# %% [markdown]
# # Text Analysis with Azure Cognitive Services Text Analytics
#
# ## Overview
# This explains the basics of writing a custom Cognitive Services Text Analytics application for analyzing long, open-form text.
# Specifically, we'll get key phrases and common entities (e.g. organizations) from each text input.
#
#
# **For the code to function properly, we will need the below two things:**
#
# 1. Text Analytics key, and
# 2. Text Analytics endpoint.
#
# Remember to keep these Azure credentials secure: we have to keep them private and secure!
#
#
# ### Getting started
# Read through the section below to learn more about Text Analytics. Then run the code block below to import and process the sample text files stored in the *TextFiles* folder.
#
# To process your own text, replace the sample text files in the *TextFiles* folder with your own .txt files.

# %% [markdown]
# ## More information on Text Data
# This notebook takes a set of text stored in the **TextFiles** folder. These input text files can be different lengths, but distinct sentences or paragraphs should be separated by a new line.
#
# You may run this notebook on the sample text provided, which include text copied from Wikipedia articles. Each text file contains content from a single Wikipedia article, with the file name indicating the name of the article.
#
# Alternatively, you may upload your own text files into the **TextFiles** folder. How you organize the text into different files will depend on your particular needs. Here is an example scenario for handling open-form survey responses:
#
# 1. Copy and paste all responses to a single question into a unique text file.
#     * Copying and pasting from Excel rows works great, as it will include a newline between each unique response.
# 2. Save each text file in a subfolder called "TextFiles" (or update the filepath in the code block below where it says "To Do").
#
# **Possible issues and how to fix it**
#
# If you run into any issues as you run the code blocks, here are some troubleshooting tips that might be helpful:
# * The Cognitive Services Text Analytics Python SDK V3 requires the following input formats:
#     * Raw Text Input
#     * Encoding: UTF-8 or UTF-16
#     * Document size less than 5,120 characters (this is handled in the import data section)
#     * Some methods (e.g. entity recognition) require a batch size of 5 or less.
#     * Input text should be in one of the following formats:
#         * a list of strings:
#
#             ```list[str]```
#         * a list of text documents:
#
#             ```list[TextDocumentInput]```
#         * or a list of dictionary representations with at least two string elements, ID and text:
#
#              ```list[dict[str, str]]```
#
#              E.g. ```texts = [{'id': Unique_Id1, 'text': Input_Text1}, {'id': Unique_ID2, 'text': Input_Text2}, ...]```
#     * If you wish to specify the ID and language on a per-item basis you must use as input a list of text documents or a list of dict representations.
#     * [More info on data limits here](https://docs.microsoft.com/en-us/azure/cognitive-services/text-analytics/overview#data-limits)
# * An "HttpOperationErrText", "HttpResponseError" or similar error indicates that the Text Analytics method did not get a correctly formatted input. Some things to check:
#     * Batch size limits.
#     * Iterating through multiple text files such that the method inputs fit one of the three options above.
#     * Any list of dictionary inputs contains unique ids for each dictionary.
# * A "list index out of range" error indicates that the input text is too long for the Text Analytics client to handle.
# * Run into other issues? Please let us know by opening an issue on the [GitHub repo](https://github.com/jenfoxbot/text-analytics-walkthrough).

# %%
# This code imports text files stored in 'TextFiles' folder and splits them 
# into dictionaries of fewer than 5,100 characters at the last new line.
# The final dictionary names are printed to the screen.

import os
# Note: your text files may have a different encoding than the one below
enc = 'utf-8'

# Import the text files in the TextFiles folder
# TO DO: Update file path as necessary
text_folder = os.path.join('TextFiles')

# Create a collection of texts with id (file name) and text (contents) properties
texts = []
for file_name in os.listdir(text_folder):
    survey_text = open(os.path.join(text_folder, file_name), encoding=enc).read()
    
    # Counter to track number of times split is done 
    text_split_counter = 0
    survey_text_list = []

    if len(survey_text) > 5100:
        while len(survey_text) > 5100:
            for char in (0,5100):
                # Get the first 5100 characters
                text_holder = survey_text[0:5100]
                # Go back to the last new line and save in a list. Save index of split
                for item in range(len(text_holder[::-1])):
                    #print(text_holder[item])
                    if text_holder[item] == "\n":
                        # Store index of last newline
                        index = item
                        # Save list up to the last newline
                        split_text = text_holder[0:index]
            #Save split text
            text = {"id": f"{file_name}.{text_split_counter}", "text": split_text}
            texts.append(text)
            # Update counter
            text_split_counter += 1
            # Remove split text from survey_text 
            survey_text = survey_text[index:len(survey_text)]
        # Save split text and update text list        
        text = {"id": f"{file_name}.{text_split_counter}", "text": survey_text}
        texts.append(text)
    
    else:
        text = {"id": file_name, "text": survey_text}
        texts.append(text)

for text_num in range(len(texts)):
    # print the open-form text
    print(texts[text_num]['id'])
    # OPTIONAL: To see all text, uncomment the following 2 lines
    #for i in range(number_of_lines):
        #print('{}\n{}\n'.format(texts[text_num]['id'], texts[text_num]['text']))
# Out:
# Congress_Corruption.txt.0
# Congress_Corruption.txt.1
# UN_History.txt.0
# UN_History.txt.1
# UN_History.txt.2
# UN_History.txt.3

# %% [markdown]
# ### Create a private file to store your Azure key and endpoint.
# The code block below installs a Python library called *dotenv*, which allows you to read environment variables from a file. You can store your Azure key and endpoint in this (untracked) file, so if you fork this project your Azure credentials remain private.
#
# Run the code below to install the library and create the *.env* file where you'll store your key and endpoint.

# %%
# WINDOWS: Use the following commands
# !pip install python-dotenv

# !echo YOUR_COG_KEY= > .env
# !echo YOUR_COG_ENDPOINT= >> .env
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-0.17.1-py2.py3-none-any.whl (18 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-0.17.1

# %% [markdown]
# ### Get your Azure key and endpoint and store them in the *.env* file.
#
# 1. In VS Code, open the *.env* file you just created. You should see two (blank) variables: *YOUR_COG_KEY* and *YOUR_COG_ENDPOINT*.
# 1. In a browser window, open the [Azure portal](https://portal.azure.com).
# 2. Select your Text Analytics resource. On the **Overview** page, click on **"Keys and endpoint"** in the menu on the left-hand side (under Resource Management).
# 1. Copy the **Key1** for your resource and paste it into the *.env* file for **YOUR_COG_KEY** after the equals sign and **between quotes**, without any spacing, like so:
#     ```YOUR_COG_KEY='COG_KEY_HERE'```
#     * Note: you can use single or double quotes (but no extra spaces!)
# 2. Copy the **endpoint** for your resource and and paste into the *.env* file for **YOUR_COG_ENDPOINT**:
#     ```YOUR_COG_ENDPOINT='COG_ENDPOINT_HERE'```
# 3. Run the code in the cell to load the variables from the *.env* file into this notebook environment.

# %%
# Import dotenv library functions and load in Azure credentials from .env file, 
# Print if key and endpoint loaded successfully.
from dotenv import load_dotenv
load_dotenv('./.env', override=True)

cog_key = os.getenv('YOUR_COG_KEY')
cog_endpoint = os.getenv('YOUR_COG_ENDPOINT')

if cog_key and cog_endpoint:
    print('Ready to use Text Analytics')
else: print('Unable to load key and/or endpoint.')
# Out:
# Ready to use Text Analytics!

# %% [markdown]
# ## Install Azure Cognitive Services Text Analytics SDK
# Run the code below to install the Text Analytics SDK onto your local environment.

# %%
# !pip install azure-ai-textanalytics --pre
# Out:
# Requirement already satisfied: azure-ai-textanalytics in c:\users\kmfj819\anaconda3\lib\site-packages (5.1.0b7)
# Requirement already satisfied: azure-common~=1.1 in c:\users\kmfj819\anaconda3\lib\site-packages (from azure-ai-textanalytics) (1.1.26)
# Requirement already satisfied: azure-core<2.0.0,>=1.14.0 in c:\users\kmfj819\anaconda3\lib\site-packages (from azure-ai-textanalytics) (1.15.0b1)
# Requirement already satisfied: six>=1.11.0 in c:\users\kmfj819\anaconda3\lib\site-packages (from azure-ai-textanalytics) (1.14.0)
# Requirement already satisfied: msrest>=0.6.0 in c:\users\kmfj819\anaconda3\lib\site-packages (from azure-ai-textanalytics) (0.6.21)
# Requirement already satisfied: requests>=2.18.4 in c:\users\kmfj819\anaconda3\lib\site-packages (from azure-core<2.0.0,>=1.14.0->azure-ai-textanalytics) (2.22.0)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\users\kmfj819\anaconda3\lib\site-packages (from msrest>=0.6.0->azure-ai-textanalytics) (1.3.0)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\kmfj819\anaconda3\lib\site-packages (from msrest>=0.6.0->azure-ai-textanalytics) (0.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kmfj819\anaconda3\lib\site-packages (from msrest>=0.6.0->azure-ai-textanalytics) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\kmfj819\anaconda3\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.14.0->azure-ai-textanalytics) (1.25.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\kmfj819\anaconda3\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.14.0->azure-ai-textanalytics) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\kmfj819\anaconda3\lib\site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.14.0->azure-ai-textanalytics) (2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\kmfj819\anaconda3\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.0->azure-ai-textanalytics) (3.1.0)

# %% [markdown]
# ## Import Cognitive Services libraries and create a Text Analytics client
#
# Run the following code to import the Cognitive Services Text Analytics library. We'll also create a client for the Text Analytics resource, which takes in two inputs: your key and endpoint that we set above.

# %%
from azure.ai.textanalytics import TextAnalyticsClient
from azure.core.credentials import AzureKeyCredential

def authenticate_client():
    ta_credential = AzureKeyCredential(cog_key)
    text_analytics_client = TextAnalyticsClient(
            endpoint=cog_endpoint, 
            credential=ta_credential)
    return text_analytics_client

client = authenticate_client()

# %% [markdown]
# ## Extract Key Phrases
# We're now ready to start using the text analytics service! First, let's get a list of key phrases from our set of texts. This helps give some indication of common themes and talking points without us having to read all of the text.
#
# When you run the code block below, it outputs key phrases for each set of texts.
# It also prints the file name, basic statistics for each text file (e.g. character count), and the number of key phrases.
#
# ### More Info
# * The key phrases service processes each input as-a-whole. This means that key phrases are extracted based on the entire input text.
# * The number of returned key phrases is proportional to the size of the input text.
# * The SDK documentation for this service can be found [here](https://docs.microsoft.com/en-us/python/api/azure-cognitiveservices-language-textanalytics/azure.cognitiveservices.language.textanalytics.textanalyticsclient?view=azure-python#key-phrases-show-stats-none--documents-none--custom-headers-none--raw-false----operation-config-).

# %%
# Load in text files and do key phrase extraction on each file
key_phrase_analysis = client.extract_key_phrases(documents=texts, show_stats=True)

#For each text file, get and print key phrases and document statistics
for doc in key_phrase_analysis:
    if not doc.is_error:
        # Print the document title
        print(doc['id'])
        # Print stats for each file
        stats = doc.statistics
        print('\nStatistics: {}'.format(stats))
        
        # Get the key phrases in this review
        key_phrases = doc.key_phrases
        print('\nNumber of Key Phrases: {}'.format(len(key_phrases)))
# 	 Dag Hammarskjöld
# 	 radical expansion
# 	 breakaway State of Katanga
# 	 successes
# 	 Kashmir
# 	 Mozambique
# 	 leadership of Algeria
# 	 management reforms
# 	 vote
# 	 Battle of Mogadishu
# 	 false renaissance
# 	 Bosnia
# 	 Taiwan
# 	 control
# 	 racism
# 	 corruption
# 	 international interventions
# 	 Haiti
# 	 USSR
# 	 Secretariat
# 	 plane crash
# 	 months
# 	 Nobel Peace Prize
# 	 wider variety of forms
# 	 attention
# 	 UK
# 	 Boutros Boutros-Ghali
# 	 effective Secretaries-General
# 	 years
# 	 bloc
# 	 size
# 	 spread of decolonization
# 	 Cyprus
# 	 dominant power
# 	 Singapore
# 	 aggression
# 	 hopes
# 	 Yugoslavia
# 	 dues
# 	 Charter
#
#
# UN_History.txt.3
#
# Statistics: {'character_count': 2128, 'transaction_count': 3}
#
# Number of Key Phrases: 64
# 	 Millennium Development Goals
# 	 organization
# 	 Sustainable Development Goals
# 	 Syrian Civil War
# 	 Libyan Civil War
# 	 international development
# 	 global security
# 	 key goals
# 	 Secretary-General
# 	 Sri Lankan Civil War
# 	 civil society
# 	 global needs
# 	 global constituency
# 	 global challenges
# 	 Millennium Summit
# 	 history
# 	 World Summit
# 	 democratic legitimacy
# 	 public debate
# 	 UN's focus
# 	 public health
# 	 UN's role
# 	 Democratic Republic of Congo
# 	 effective peacekeeping efforts
# 	 largest gathering of world leaders
# 	 Portuguese diplomat António Guterres
# 	 United Nations Security Council Resolution
# 	 chemical weapons inspectors
# 	 observers
# 	 areas
# 	 poverty reduction
# 	 final battles
# 	 Kivu conflict
# 	 gender equality
# 	 conflicts
# 	 Darfur
# 	 NATO countries
# 	 commitment
# 	 member states
# 	 human rights
# 	 diplomacy
# 	 actions
# 	 Sudan
# 	 administration
# 	 worst loss of life
# 	 MDGs
# 	 day meeting
# 	 Ban Ki-moon
# 	 emphasis
# 	 personnel
# 	 adoption
# 	 Refugees
# 	 peacekeepers
# 	 crises
# 	 candidates
# 	 internal review
# 	 Haiti earthquake
# 	 High Commissioner
# 	 century
# 	 accountability
# 	 transparency
# 	 addition
# 	 systemic failure
# 	 Progress

# %% [markdown]
# ## Extract Known Entities
#
# Next, let's look for common entities in our text responses. *Entities* are things that reference some commonly understood type of item.
# For example, a location, a person, or an organization. The following code block pulls out "Organization", "Person", "Location, and "Other" entities.
#
# A full list of supported entities can be found [here](https://docs.microsoft.com/en-us/azure/cognitive-services/text-analytics/named-entity-types?tabs=general).
#
# ### More Info
# Some entities are sufficiently well-known to have an associated Wikipedia page. The Text Analytics service can also return the URL for that page using the "recognize_linked_entities" method. For more information, [check out the Python SDK method documentation here](https://docs.microsoft.com/en-us/python/api/azure-ai-textanalytics/azure.ai.textanalytics.textanalyticsclient?view=azure-python#recognize-entities-documents----kwargs-)

# %%
# Use the client and reviews you created previously to get named entities
# Set batch size to be 5 (max input for recognize_entities)
batch_size = 5

for i in range(0, len(texts), batch_size):
    # Create subset of dictionaries
    batch = texts[i:i+batch_size] 
    #Run entity analysis on sets of 5 or fewer inputs 
    entity_analysis = client.recognize_entities(batch)
    
    # Create a list of the entity analysis results
    docs = [doc for doc in entity_analysis if not doc.is_error]

    # Iterate through texts and print entity analysis results
    for idx, doc in enumerate(docs):
        # Print text ID 
        print("\n" + doc['id'])
        for entity in doc.entities:
            # Only get Organization and Other entitites
            # TO DO: Add or remove entities to this list according to needs/interests
            if entity.category in ['Organization','Person', 'Location', 'Other']:
                print(' - {}: {} (Confidence: {})'.format(entity.category, entity.text, entity.confidence_score))
# Out:
# Congress_Corruption.txt.0
#  - Organization: Schweizer Illustrierte magazine (Confidence: 0.85)
#  - Person: Imelda Marcos (Confidence: 0.99)
#  - Location: Third (Confidence: 0.4)
#  - Location: World (Confidence: 0.4)
#  - Organization: McKinsey (Confidence: 0.96)
#  - Person: Rajiv Gandhi (Confidence: 0.99)
#  - Location: Switzerland (Confidence: 0.98)
#  - Location: India (Confidence: 0.99)
#  - Organization: Schweizer Illustrierte (Confidence: 0.78)
#  - Person: Amal Datta (Confidence: 0.99)
#  - Organization: Indian Parliament (Confidence: 0.88)
#  - Organization: Lok Sabha (Confidence: 0.62)
#  - Person: Shivraj Patil (Confidence: 0.98)
#  - Person: Rajiv Gandhi (Confidence: 0.99)
#  - Person: Subramanian Swamy (Confidence: 0.98)
#  - Organization: Central Bureau of Investigation (Confidence: 0.95)
#  - Person: Nehru-Gandhi (Confidence: 0.95)
#  - Person: Ram Jethmalani (Confidence: 0.99)
#  - Organization: Rajya Sabha (Confidence: 0.81)
#  - Location: India (Confidence: 0.94)
#  - Organization: Congress (Confidence: 0.76)
#  - Organization: KGB (Confidence: 0.94)
#  - Organization: Times of India (Confidence: 0.88)
#  - Organization: The Hindu (Confidence: 0.84)
#  - Person: Rajiv Gandhi (Confidence: 0.99)
#  - Organization: KGB (Confidence: 0.97)
#  - Organization: Russian government (Confidence: 0.53)
#  - Person: Yevgenia Albats (Confidence: 0.99)
#  - Person: Catherine Fitzpatrick (Confidence: 0.99)
#  - Person: Viktor Chebrikov (Confidence: 0.99)
#  - Organization: KGB (Confidence: 0.92)
#  - Organization: KGB (Confidence: 0.98)
#  - Person: Gandhi (Confidence: 1.0)
#  - Organization: KGB (Confidence: 0.98)
#  - Person: Albats (Confidence: 0.97)
#  - Person: Chebrikov (Confidence: 0.99)
#  - Organization: Central Committee of the Communist Party of the Soviet Union (Confidence: 0.86)
#  - Person: Rajiv Gandhi (Confidence: 0.99)
#  - Person: Sonia Gandhi (Confidence: 0.99)
#  - Person: Rahul Gandhi (Confidence: 0.99)
#  - Organization: USSR Council of Ministers (Confidence: 0.88)
#  - Person: Subramanian Swamy (Confidence: 0.96)
#  - Location: Delhi (Confidence: 0.48)
#  - Organization: High Court (Confidence: 0.85)
#  - Organization: Court (Confidence: 0.5)
#  - Organization: CBI (Confidence: 0.95)
#  - Organization: CBI (Confidence: 0.94)
#  - Organization: Court (Confidence: 0.58)
#  - Location: Russia (Confidence: 0.94)
#  - Person: Rajiv Gandhi (Confidence: 0.77)
#  - Person: Rajiv Gandhi (Confidence: 0.99)
#  - Location: Sriperumbudur (Confidence: 0.89)
#  - Location: village (Confidence: 0.61)
#  - Location: Madras (Confidence: 0.97)
#  - Location: Chennai (Confidence: 0.98)
#  - Organization: Sriperumbudur Lok Sabha Congress (Confidence: 0.56)
#  - Person: Thenmozhi Rajaratnam (Confidence: 0.98)
#  - Organization: Liberation Tigers of Tamil Eelam (Confidence: 0.78)
#  - Person: Gandhi (Confidence: 0.99)
#  - Person: Veer Bhumi (Confidence: 0.61)
#  - Location: Delhi (Confidence: 0.98)
#  - Person: Rajiv Gandhi (Confidence: 0.98)
#  - Person: Gandhi (Confidence: 0.95)
#  - Person: Rajaratnam (Confidence: 0.75)
#  - Person: Haribabu (Confidence: 0.99)
#  - Person: Gandhi (Confidence: 0.99)
#  - Organization: All India Institute of Medical Sciences (Confidence: 0.88)
#  - Location: New Delhi (Confidence: 0.97)
#  - Person: Gandhi (Confidence: 0.99)
#  - Location: Veer Bhumi (Confidence: 0.53)
#  - Location: river Yamuna (Confidence: 0.92)
#  - Location: shrines (Confidence: 0.73)
#  - Person: Indira Gandhi (Confidence: 0.99)
#  - Person: Sanjay Gandhi (Confidence: 0.99)
#  - Person: Jawaharlal Nehru (Confidence: 0.99)
#  - Location: Rajiv Gandhi Memorial (Confidence: 0.55)
#  - Location: Sriperumbudur (Confidence: 0.82)
#  - Organization: Supreme Court (Confidence: 0.93)
#  - Person: K. T. Thomas (Confidence: 0.96)
#  - Person: Gandhi (Confidence: 0.99)
#  - Organization: LTTE (Confidence: 0.9)
#  - Person: Prabhakaran (Confidence: 0.97)
#  - Organization: Indian Peace Keeping Force (Confidence: 0.92)
#  - Organization: IPKF (Confidence: 0.93)
#  - Location: Sri Lanka (Confidence: 0.98)
#  - Organization: IPKF (Confidence: 0.82)
#  - Person: Gandhi (Confidence: 0.91)
#  - Organization: PLOTE (Confidence: 0.95)
#  - Location: Maldives (Confidence: 0.98)
#  - Person: Thileepan (Confidence: 0.91)
#  - Organization: LTTE (Confidence: 0.84)
#
# Congress_Corruption.txt.1
#  - Organization: Jain Commission (Confidence: 0.9)
#  - Person: Rajiv Gandhi (Confidence: 0.97)
#  - Person: Chandraswami (Confidence: 0.98)
#  - Person: Nalini Sriharan (Confidence: 0.99)
#  - Person: Rajiv Gandhi (Confidence: 0.95)
#  - Person: Nalini (Confidence: 0.99)
#  - Person: Nalini (Confidence: 0.99)
#  - Organization: LTTE (Confidence: 0.84)
#  - Person: Sriharan alias (Confidence: 0.89)
#  - Person: Murugan (Confidence: 0.95)
#  - Person: Nalini (Confidence: 0.99)
#  - Person: Harithra (Confidence: 0.98)
#  - Location: prison (Confidence: 0.91)
#  - Person: Nalini (Confidence: 0.99)
#  - Person: Rajiv (Confidence: 0.99)
#  - Person: Sonia Gandhi (Confidence: 1.0)
#  - Person: Nalini (Confidence: 0.99)
#  - Person: Gandhi (Confidence: 0.99)
#  - Person: Priyanka Gandhi Vadra (Confidence: 0.99)
#  - Person: Nalini (Confidence: 0.99)
#  - Location: Vellore Central Prison (Confidence: 0.86)
#  - Person: Nalini (Confidence: 0.99)
#  - Person: Gandhi (Confidence: 0.99)
#  - Location: India (Confidence: 0.73)
#  - Person: Murugan (Confidence: 0.98)
#  - Person: Suthendraraja (Confidence: 0.97)
#  - Person: Santhan (Confidence: 0.97)
#  - Person: Perarivalan (Confidence: 0.98)
#  - Person: Arivu (Confidence: 0.97)
#  - Organization: Madras High Court (Confidence: 0.81)
#  - Person: Nalini (Confidence: 0.99)
#  - Organization: Madras High Court (Confidence: 0.79)
#  - Location: prison (Confidence: 0.85)
#  - Organization: government (Confidence: 0.61)
#  - Person: Murugan (Confidence: 0.98)
#  - Person: Santhan (Confidence: 0.98)
#  - Person: Perarivalan (Confidence: 0.97)
#  - Organization: Supreme Court of India (Confidence: 0.84)
#  - Person: Murugan (Confidence: 0.97)
#  - Person: Santhan (Confidence: 0.97)
#  - Person: Perarivalan (Confidence: 0.97)
#  - Location: Tamil Nadu (Confidence: 0.62)
#  - Person: Rajiv Gandhi (Confidence: 0.98)
#  - Person: A. G. Perarivalan (Confidence: 0.98)
#  - Person: Nalini (Confidence: 0.98)
#  - Organization: Government of India (Confidence: 0.8)
#  - Organization: Supreme Court (Confidence: 0.95)
#  - Organization: Constitution Bench (Confidence: 0.57)
#  - Organization: Jain Commission (Confidence: 0.94)
#  - Location: Tamil Nadu (Confidence: 0.69)
#  - Person: Karunanidhi (Confidence: 0.99)
#  - Organization: Congress (Confidence: 0.89)
#  - Person: I. K. Gujral (Confidence: 0.73)
#  - Organization: LTTE (Confidence: 0.94)
#  - Person: Anton Balasingham (Confidence: 1.0)
#  - Organization: NDTV (Confidence: 0.89)
#  - Location: memorial (Confidence: 0.51)
#  - Location: Veer Bhumi (Confidence: 0.77)
#  - Person: Gandhi (Confidence: 0.98)
#  - Location: Delhi (Confidence: 0.99)
#  - Organization: Indian National Congress Party (Confidence: 0.97)
#  - Person: Gandhi (Confidence: 0.98)
#  - Person: Rajiv Gandhi (Confidence: 0.99)
#  - Person: Gandhi-Nehru (Confidence: 0.98)
#  - Organization: Zee News (Confidence: 0.92)
#  - Person: Gandhi (Confidence: 0.99)
#  - Person: Rajiv Awas Yojana (Confidence: 0.9)
#  - Person: Rajiv Gandhi Udyami Mitra Yojana (Confidence: 0.7)
#  - Location: Haryana (Confidence: 0.7)
#  - Person: Anil Vij (Confidence: 0.99)
#  - Location: stadia (Confidence: 0.68)
#  - Location: India (Confidence: 0.99)
#  - Location: stadia (Confidence: 0.75)
#  - Location: Haryana (Confidence: 0.95)
#  - Person: Vij (Confidence: 0.92)
#  - Organization: Congress (Confidence: 0.84)
#  - Person: Kuldeep Sharma (Confidence: 0.99)
#
# UN_History.txt.0
#  - Organization: UN (Confidence: 0.94)
#  - Person: Roosevelt (Confidence: 0.99)
#  - Person: Churchill (Confidence: 0.98)
#  - Location: White House (Confidence: 0.71)
#  - Person: Roosevelt (Confidence: 0.98)
#  - Organization: United Nations (Confidence: 0.94)
#  - Location: U.S. (Confidence: 0.96)
#  - Location: U.S. (Confidence: 0.95)
#  - Organization: Allies (Confidence: 0.73)
#  - Person: Byron (Confidence: 0.96)
#  - Organization: United Nations (Confidence: 0.94)
#  - Person: Roosevelt (Confidence: 0.99)
#  - Person: Churchill (Confidence: 0.99)
#  - Person: Roosevelt (Confidence: 0.95)
#  - Person: Harry Hopkins (Confidence: 0.99)
#  - Location: France (Confidence: 0.99)
#  - Person: Stalin (Confidence: 0.99)
#  - Person: Roosevelt (Confidence: 0.99)
#
# UN_History.txt.1
#  - Person: Roosevelt (Confidence: 0.99)
#  - Location: United States (Confidence: 0.97)
#  - Location: United Kingdom (Confidence: 0.97)
#  - Location: Soviet Union (Confidence: 0.95)
#  - Location: Republic of China (Confidence: 0.88)
#  - Organization: United Nations (Confidence: 0.93)
#  - Person: Roosevelt (Confidence: 0.97)
#  - Person: Churchill (Confidence: 0.96)
#  - Person: Maxim Litvinov (Confidence: 0.99)
#  - Location: USSR (Confidence: 0.95)
#  - Person: T. V. Soong (Confidence: 0.99)
#  - Location: China (Confidence: 0.98)
#  - Organization: United Nations (Confidence: 0.82)
#  - Organization: United Nations (Confidence: 0.92)
#  - Organization: Allies (Confidence: 0.48)
#  - Organization: Axis (Confidence: 0.57)
#  - Organization: League of Nations (Confidence: 0.97)
#  - Person: Roosevelt (Confidence: 0.99)
#  - Person: Churchill (Confidence: 0.99)
#  - Person: Stalin (Confidence: 0.99)
#  - Organization: UN (Confidence: 0.88)
#  - Organization: Allied Big Four (Confidence: 0.8)
#  - Location: United States (Confidence: 0.97)
#  - Location: United Kingdom (Confidence: 0.97)
#  - Location: Soviet Union (Confidence: 0.91)
#  - Location: Republic of China (Confidence: 0.91)
#  - Location: Yalta (Confidence: 0.94)
#  - Location: Moscow (Confidence: 0.98)
#  - Organization: United Nations (Confidence: 0.96)
#  - Organization: UN (Confidence: 0.46)
#  - Location: San Francisco (Confidence: 0.98)
#  - Person: Winston Churchill (Confidence: 0.99)
#  - Person: Roosevelt (Confidence: 0.99)
#  - Location: France (Confidence: 0.99)
#  - Location: Paris (Confidence: 0.95)
#  - Organization: United Nations (Confidence: 0.71)
#  - Organization: UN (Confidence: 0.96)
#  - Organization: Security Council (Confidence: 0.86)
#  - Location: US (Confidence: 0.97)
#  - Location: UK (Confidence: 0.98)
#  - Location: France (Confidence: 0.99)
#  - Location: Soviet Union (Confidence: 0.92)
#  - Location: Republic of China (Confidence: 0.87)
#  - Organization: General Assembly (Confidence: 0.74)
#  - Organization: Security Council (Confidence: 0.91)
#  - Location: London (Confidence: 0.99)
#  - Location: Iranian Azerbaijan (Confidence: 0.86)
#  - Location: Greece (Confidence: 0.99)
#  - Organization: General Assembly (Confidence: 0.88)
#  - Location: Headquarters (Confidence: 0.71)
#  - Organization: UN (Confidence: 0.97)
#  - Organization: Security Council (Confidence: 0.93)
#  - Organization: UN (Confidence: 0.97)
#  - Location: Namibia (Confidence: 0.99)
#  - Location: South Africa (Confidence: 0.97)
#  - Location: Rouge Cambodia (Confidence: 0.69)
#  - Organization: UN (Confidence: 0.96)
#  - Location: US (Confidence: 0.53)
#  - Location: Kuwait (Confidence: 0.95)
#  - Person: Brian Urquhart (Confidence: 1.0)
#  - Organization: UN (Confidence: 0.96)
#  - Location: US (Confidence: 0.58)
#  - Person: Ronald Reagan (Confidence: 0.99)
#  - Organization: United Nations Educational, Scientific and Cultural Organization (Confidence: 0.96)
#  - Organization: UNESCO (Confidence: 0.95)
#  - Location: UK (Confidence: 0.99)
#  - Location: Singapore (Confidence: 0.99)
#  - Person: Boutros Boutros-Ghali (Confidence: 0.99)
#  - Organization: Secretariat (Confidence: 0.51)
#  - Person: Kofi Annan (Confidence: 0.99)
#  - Location: US (Confidence: 0.99)
#  - Organization: UN (Confidence: 0.9)
#  - Organization: UN (Confidence: 0.84)
#  - Organization: UN (Confidence: 0.97)
#  - Location: Somalia (Confidence: 0.99)
#  - Location: Haiti (Confidence: 0.99)
#  - Location: Mozambique (Confidence: 0.99)
#  - Location: Yugoslavia (Confidence: 0.92)
#  - Organization: UN (Confidence: 0.91)
#  - Location: Somalia (Confidence: 0.95)
#  - Location: US (Confidence: 0.88)
#  - Organization: UN (Confidence: 0.95)
#  - Location: Bosnia (Confidence: 0.98)
#  - Organization: UN Assistance Mission for (Confidence: 0.86)
#  - Location: Rwanda (Confidence: 0.5)
#  - Organization: Security Council (Confidence: 0.94)
#  - Organization: UN (Confidence: 0.97)
#  - Organization: United Nations Security Council (Confidence: 0.91)
#  - Organization: NATO (Confidence: 0.97)
#  - Organization: Kosovo Force (Confidence: 0.91)
#  - Organization: UN (Confidence: 0.89)
#  - Location: Afghanistan (Confidence: 0.95)
#  - Organization: NATO (Confidence: 0.98)
#  - Location: United States (Confidence: 0.9)
#  - Location: Iraq (Confidence: 0.98)
#  - Organization: UN Security Council (Confidence: 0.93)
# UN_History.txt.3
#  - Person: Ban Ki-moon (Confidence: 0.99)
#  - Organization: UN (Confidence: 0.92)
#  - Location: Sudan (Confidence: 0.79)
#  - Location: Democratic Republic of Congo (Confidence: 0.93)
#  - Organization: UN (Confidence: 0.92)
#  - Location: Haiti (Confidence: 0.76)
#  - Organization: United Nations Security Council (Confidence: 0.91)
#  - Organization: NATO (Confidence: 0.92)
#  - Organization: UN (Confidence: 0.97)
#  - Organization: UN (Confidence: 0.97)
#  - Organization: UN (Confidence: 0.97)
#  - Person: António Guterres (Confidence: 0.99)
#  - Organization: UN (Confidence: 0.86)
#  - Person: Guterres (Confidence: 0.99)

# %% [markdown]
# With this we have completed our first machine learning on text to get some insights using azure text analytics. There are many other text services azure offers which are worth to have a look.
#
# https://azure.microsoft.com/en-in/services/cognitive-services/text-analytics/
